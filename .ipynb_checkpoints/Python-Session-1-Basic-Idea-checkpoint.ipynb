# %% [markdown]
# # Python notebooks will works by using python kernal
# - Python kernal dot, is dot is white color: idle state, ready to execute to code
# - Python kernal black ========> it is busy
# - Python kernal will run the code step by step
# - If you kernal black color, do not run any codes
# - Python kernal is red ====> kernal is dead

# %% [markdown]
# Plus Sign
#
# Click on plus sign ==== it will create new cells
#
# New Cell is used to provide some input
#
# Input means write some code
#
# When you run it will provide output
#
# Markdown short cut: esc+m at a time
#
# Whenever if you are seeing IN which means cell is in code mode
#
# Code Mode ===== In at cell both are same
#
# If you wamt wrire any story change code mode to Markdown Mode
#
# Select the cell double click

# %%
a=20
a

# Shift+Enter at a time
#esc-y to return the code mode
# Out:
# 20

# %% [markdown]
# ## Python

# %%
a=20 # 20 is saved in a variable
a
# Out:
# 20

# %% [markdown]
# - Python is easy
#   - Hello
#   - How do you do
# - Python is my friend
# - Python is used in DS and AI

# %% [markdown]
# - Code Mode
# - Markdown Mode

# %%
# Packages

# Package Name : Random

# import <package_name>
# dir(<package_name>)  # It will return methods
# help(<package_name>.<method_name>)

# %%
import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,100) # Shift + Tab for help cursor should be inside the bracket
# Out:
# 90

# %%
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
import math

# %%
math.sin(3.14159265359)
# Out:
# -2.0682310711021444e-13

# %%
import math
math
# Out:
# <module 'math' (built-in)>

# %%
import random
random
#.py
#vscode
#pycharm
#notepad++
# Out:
# <module 'random' from 'C:\\Users\\arpit\\anaconda3\\Lib\\random.py'>

# %%
# We Imported Package
# We have seen where the package is located

# %%
# Package Name: Keyword
import keyword

# %%
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'issoftkeyword',
#  'kwlist',
#  'softkwlist']

# %%
# read the kwlist

# <pname>.<method name>
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
#package name: cv2
#cv2= computer vision 

ModuleNotFoundError
Because the package is no there in our pc
We need to install the package
We need the help of google to download it first

# Shift + Enter
Search Python Organization
Pip install opencv-python
Where Will Install ====> Anaconda Command Prompt
# Out:
#   Cell In[32], line 5
#     Because the package is no there in our pc
#             ^
# SyntaxError: invalid syntax

# %%
pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# ...
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
cv2
# Out:
# <module 'cv2' from 'C:\\Users\\arpit\\anaconda3\\Lib\\site-packages\\cv2\\__init__.py'>

# %% [markdown]
# ## Variables:

# %% [markdown]
# - Variable term vary
# - You Want to save some values at some place, that place is called varibles
# - variables and constant

# %%
number = 100  # 100 value is stored in a varibale called number 
number # so here number is a varible
# Out:
# 100

# %%
number = 200
number
# Out:
# 200

# %%
# so here first number has 100
#         Second numnber has 200
# Number is charging its value
# Thats Why we are calling number as variable

# %% [markdown]
# **Rules to define Variables**

# %% [markdown]
# $ Checking $

# %%
#Upper case
NUMBER = 300
NUMBER
# Out:
# 300

# %%
#Lower Case
number =400
number
# Out:
# 400

# %%
#Combination of Lower and upper case
NUMber=500
NUMber
# Out:
# 500

# %%
# Combination of letters and numbers , numbers as suffix
number123=600
number123
# Out:
# 600

# %%
# Combination of letters and numbers, numbers as prefix
123number=700
123number
# Out:
#   Cell In[9], line 2
#     123number=700
#       ^
# SyntaxError: invalid decimal literal

# %%
# spl charcters
number%=800
number%
# Out:
#   Cell In[10], line 3
#     number%
#            ^
# SyntaxError: invalid syntax

# %%
#underscore
number_=900
number_
# Out:
# 900

# %%
sum=700
sum
# Out:
# 700

# %% [markdown]
# **Note**:
#
# sum is a math operation it will works
#
# but do not use as variable

# %%
number_one=700
number_one
# Out:
# 700

# %%
_=900
_
# Out:
# 900

# %%
############### Basics###############
1) Basic syntax
2) Variables
3) python packages information
4) Basic python code
5) Conditional statements
6) functions
7) loop

################ Leve-2###############
1) Strings
2) List
3) dictionary
4) tuples ======== write up 
5) sets
6) file handling sessions

========== 2 weeks gap ============== statistics theory
EDA: python

############ Level-3################
1) OOPS concept in python
2) how to create your own packages
3) FLASK APPS
# Out:
#   Cell In[16], line 2
#     1) Basic syntax
#      ^
# SyntaxError: unmatched ')'

# %%
num1=eval(input("enter a number1:"))
num2=eval(input("enter a number2:"))
add=num1+num2
print(add)
# Out:
# enter a number1: 100
# enter a number2: 200
# 300

# %%
# error-1: Name eror: num3 not defined
num1=eval(input("enter a number1:"))
num2=eval(input("enter a number2:"))
add=num1+num3
print(add)
# Out:
# enter a number1: 100
# enter a number2: 300
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 num1=eval(input("enter a number1:"))
#       3 num2=eval(input("enter a number2:"))
# ----> 4 add=num1+num3
#       5 print(add)
#
# NameError: name 'num3' is not defined

# %%
 # error-2: 
num1=eval(input("enter a number1:")
num2=eval(input("enter a number2:"))
add=num1+num2
print(add)
# Out:
#   Cell In[3], line 2
#     num1=eval(input("enter a number1:")
#              ^
# SyntaxError: '(' was never closed

# %%
# error-3: 
num1=eval(input("enter a number1:"))
num2=eval(input("enter a number2:"))
add=num1/num2
print(add)
# Out:
# enter a number1: 100
# enter a number2: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 num1=eval(input("enter a number1:"))
#       3 num2=eval(input("enter a number2:"))
# ----> 4 add=num1/num2
#       5 print(add)
#
# ZeroDivisionError: division by zero

# %%
# error-4: 
num1=input("enter a number1:") #string
num2=eval(input("enter a number2:"))#int
add=num1/num2   # string/int 
print(add)
# Out:
# enter a number1: 10
# enter a number2: 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 num1=input("enter a number1:")
#       3 num2=eval(input("enter a number2:"))
# ----> 4 add=num1/num2
#       5 print(add)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
 # error-5: 
num1=input("enter a number1:") #string
num2=eval(input("enter a number2:"))#int
add=num1/num2   # string/int 
print add
# Out:
#   Cell In[6], line 5
#     print add
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# error- 6: 
num1=eval(input("enter a number1:")) 
num2=eval(input("enter a number2:"))
add=num1/num2   # string/int 
Print(add)
# Out:
# enter a number1: 100
# enter a number2: 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3 num2=eval(input("enter a number2:"))
#       4 add=num1/num2   # string/int
# ----> 5 Print(add)
#
# NameError: name 'Print' is not defined

# %% [markdown]
# ### Possible Errors:
# - Name Error
# - Syntax Error: '(' was never closed
# -  Zero Division Error: division by zero
# -  Type Error: unsupported operand type(s) for /: 'str' and 'int'
# -  Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
Suppose you have written 500 lines of code
At 200 you got an error
This error might not impact your code
So you want to excetute after 200 line also

Exception Handling

# %% [markdown]
# $try$-$except$
#
# - there are two blocks
# - one try block
# - another is exception block
# - your code will be there in try block
# - error capture will happens in except block
# - Indentation: space
# - red :space/indentation not maintained properly
# - indentation has min 4 characters?
# - : is there, then indentation will be there

# %%
try:
    num1= 10
    num2= 0
    num3=20
    add = num1/num2   #10/0  ====> zero 
    print(add)

except:
    print("Error is there,check code")
# Out:
# Error is there,check code

# %%
num1= 10
num2= 0
num3=20
add = num1/num2   #10/0  ====> zero 
print(add)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[18], line 4
#       2 num2= 0
#       3 num3=20
# ----> 4 add = num1/num2   #10/0  ====> zero
#       5 print(add)
#
# ZeroDivisionError: division by zero

# %%
# Method-1
try:
    num1= 10
    num2= 30
    num3=20
    add = num1/num2   #10/0  ====> zero 
    print(add)

except:
    print("Error is there,check code")
# Out:
# 0.3333333333333333

# %%
# Method-2
try:
    num1= 10
    num2= 0
    num3=20
    add = num1/num2   #10/0  ====> zero 
    print(add)

except:
    print("Error is there,check code")
# Out:
# Error is there,check code

# %%
#wap ask the user enter 3 numbers and find the average
num1=eval(input("enter number-1:"))
num2=eval(input("enter number-2:"))
num3=eval(input("enter number-3:")) 
average=(num1+num2+num3)/3
print("THe average of {},{} and {} is {}".format(num1,num2,num3,average))
# Out:
# enter number-1: 10
# enter number-2: 20
# enter number-3: 30
# THe average of 10,20 and 30 is 20.0

# %%
try:
    num1=eval(input("enter number-1:"))
    num2=eval(input("enter number-2:"))
    num3=eval(input("enter number-3:")) 
    average=(num1+num2+num3333)/3
    print("THe average of {},{} and {} is {}".format(num1,num2,num3,average))
except Exception as e:
    print(e)

#error-1: name error
# Out:
# enter number-1: 20
# enter number-2: 30
# enter number-3: 40
# name 'num3333' is not defined

# %%
try:
    num1=eval(input("enter number-1:"))
    num2=eval(input("enter number-2:"))
    num3=eval(input("enter number-3:")) 
    average=(num1+num2+num3)/0
    print("THe average of {},{} and {} is {}".format(num1,num2,num3,average))
except Exception as e:
    print(e)

#error-2: division by zero
# Out:
# enter number-1: 20
# enter number-2: 30
# enter number-3: 40
# division by zero

# %%
try:
    num1=eval(input("enter number-1:"))
    num2=eval(input("enter number-2:"))
    num3=eval(input("enter number-3:")) 
    average=(num1+num2+num3)/3
print("THe average of {},{} and {} is {}".format(num1,num2,num3,average))
except Exception as e:
    print(e)

#error-1: Syntax Error
# Out:
#   Cell In[7], line 6
#     print("THe average of {},{} and {} is {}".format(num1,num2,num3,average))
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
# Wap ask the user enter a number and find the square of the number
#Sir if we get more than 1 error in try block, which error :-Answer first error
try: 
    num=eval(input("Enter a number"))
    sqr=num*num222
    print("Square of {} is {}".format(num,sqr)) 
except Exception as e:
    print(e)
# Out:
# Enter a number 10
# name 'num222' is not defined

# %%
Sys 
Traceback
looger

# %%
import sys
sys.exc_info()
# Out:
# (None, None, None)

# %%
 number=input('number: ') [:2]
number
# Out:
# number:  2345
# '23'

# %%
number # list
# Out:
# '23'

# %%
 try: 
    num=eval(input("Enter a number"))
    sqr=num*num222
    print("Square of {} is {}".format(num,sqr)) 
except Exception as e:
    print(e)    #capture the eroor   
    print('hello ')  #hello
# Out:
# Enter a number 10
# name 'num222' is not defined
# hello

# %%
 try: 
    num=eval(input("Enter a number"))
    sqr=num*num222
    print("Square of {} is {}".format(num,sqr)) 
except Exception as e:
    print('hai')
    print(e)    #capture the eroor   
    print('hello ')  #hello

# %%
# If no identation gap its printing

# %%
try: 
    num=eval(input("Enter a number"))
    sqr=num*num
    print("Square of {} is {}".format(num,sqr)) 
except Exception as e:
    print('hai')
    print(e)   
    print('hello ') 
    
print('python')
print(1)
print(2)

# num=100
# error ===== exception
              # hai
              # error
#python
#1
#2
# Out:
# Enter a number 10
# Square of 10 is 100
# python
# 1
# 2

# %%
try: 
    num=eval(input("Enter a number"))
    sqr=num*num22
    print("Square of {} is {}".format(num,sqr)) 
except Exception as e:
    print('hai')
    print(e)   
    print('hello ') 
    
print('python')
print(1)
print(2)

# num=100
# error ===== exception
              # hai
              # error
#python
#1
#2
# Out:
# Enter a number 2
# hai
# name 'num22' is not defined
# hello
# python
# 1
# 2

# %%
print('100')
print(1)
# Out:
# 100
# 1

# %%
try:
    print('Hello')
# Out:
#   Cell In[5], line 2
#     print('Hello')
#                   ^
# _IncompleteInputError: incomplete input

# %%
- if your code is withour error, try block will execute
- if your code has errors, it will redirect to except block
- what ever you written inside except block that will run
- try and exception is together 
- Ones try and exceptions code are complete, it try to look any other lines of code are there

# %%
print("==============")
print(3+5)
print('*********') 
try: 
    num=eval(input("Enter a number"))
    sqr=num*num22
    print("Square of {} is {}".format(num,sqr)) 
except Exception as e:
    print('hai')
    print(e)   
    print('hello ') 
    
print('python')
print(1)
print(2)
# Out:
# ==============
# 8
# *********
# Enter a number 2
# hai
# name 'num22' is not defined
# hello
# python
# 1
# 2

# %%
print("==============")
print(3+5)
print('*********')
try: 
    num=eval(input("Enter a number"))
    sqr=num*num22
    print("Square of {} is {}".format(num,sqr))

print('out')

except Exception as e:
    print('hai')
    print(e)   
    print('hello ') 
    
print('python')
print(1)
print(2)
# Out:
#   Cell In[7], line 9
#     print('out')
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
print("==============")
print(3+5)
print('*********')
try: 
    num=eval(input("Enter a number"))
    sqr=num*num22
    print("Square of {} is {}".format(num,sqr))

 print('out')

except Exception as e:
    print('hai')
    print(e)   
    print('hello ') 
    
print('python')
print(1)
print(2)
# Out:
#   File <string>:9
#     print('out')
#                 ^
# IndentationError: unindent does not match any outer indentation level

# %%
** Note:

    5 qns = try-expect
